# %% [markdown]
# # 1.Import the necessary libraries if you are starting a new notebook. Using the same data as the previous lab: we_fn_use_c_marketing_customer_value_analysis.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 2.Find all of the categorical data. Save it in a categorical_df variable.

# %%
customer_df = pd.read_csv(r'C:\Users\duyadong\Ironhack\Week_4\Day_1\Afternoon\lab-cleaning-categorical-data\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')

# %%
categorical_df =customer_df.select_dtypes(include=object)

# %% [markdown]
# # 3.Check for NaN values.

# %%
categorical_df.isna().sum()
# Out:
# Customer             0
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %% [markdown]
# # 4.Check all unique values of columns.

# %%
for col in categorical_df:
    print(categorical_df[col].unique())
# Out:
# ['BU79786' 'QZ44356' 'AI49188' ... 'TD14365' 'UP19263' 'Y167826']
# ['Washington' 'Arizona' 'Nevada' 'California' 'Oregon']
# ['No' 'Yes']
# ['Basic' 'Extended' 'Premium']
# ['Bachelor' 'College' 'Master' 'High School or Below' 'Doctor']
# ['2/24/11' '1/31/11' '2/19/11' '1/20/11' '2/3/11' '1/25/11' '1/18/11'
#  '1/26/11' '2/17/11' '2/21/11' '1/6/11' '2/6/11' '1/10/11' '1/17/11'
#  '1/5/11' '2/27/11' '1/14/11' '1/21/11' '2/5/11' '1/29/11' '2/28/11'
#  '2/12/11' '2/2/11' '2/7/11' '1/22/11' '2/13/11' '1/15/11' '1/8/11'
#  '1/11/11' '1/28/11' '2/8/11' '2/23/11' '1/2/11' '2/16/11' '1/27/11'
#  '1/23/11' '1/9/11' '2/11/11' '2/4/11' '2/1/11' '2/15/11' '2/26/11'
#  '1/16/11' '1/1/11' '2/10/11' '1/24/11' '2/25/11' '1/12/11' '2/9/11'
#  '1/19/11' '1/4/11' '2/14/11' '2/20/11' '2/18/11' '1/3/11' '1/13/11'
#  '1/30/11' '2/22/11' '1/7/11']
# ['Employed' 'Unemployed' 'Medical Leave' 'Disabled' 'Retired']
# ['F' 'M']
# ['Suburban' 'Rural' 'Urban']
# ['Married' 'Single' 'Divorced']
# ['Corporate Auto' 'Personal Auto' 'Special Auto']
# ['Corporate L3' 'Personal L3' 'Corporate L2' 'Personal L1' 'Special L2'
#  'Corporate L1' 'Personal L2' 'Special L1' 'Special L3']
# ['Offer1' 'Offer3' 'Offer2' 'Offer4']
# ['Agent' 'Call Center' 'Web' 'Branch']
# ['Two-Door Car' 'Four-Door Car' 'SUV' 'Luxury SUV' 'Sports Car'
#  'Luxury Car']
# ['Medsize' 'Small' 'Large']

# %% [markdown]
# # 5.Check dtypes. Do they all make sense as categorical data?

# %%
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Customer           9134 non-null   object
#  1   State              9134 non-null   object
#  2   Response           9134 non-null   object
#  3   Coverage           9134 non-null   object
#  4   Education          9134 non-null   object
#  5   Effective To Date  9134 non-null   object
#  6   EmploymentStatus   9134 non-null   object
#  7   Gender             9134 non-null   object
#  8   Location Code      9134 non-null   object
#  9   Marital Status     9134 non-null   object
#  10  Policy Type        9134 non-null   object
#  11  Policy             9134 non-null   object
#  12  Renew Offer Type   9134 non-null   object
#  13  Sales Channel      9134 non-null   object
#  14  Vehicle Class      9134 non-null   object
#  15  Vehicle Size       9134 non-null   object
# dtypes: object(16)
# memory usage: 1.1+ MB

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0  Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1   Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2   Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3  Corporate L2           Offer1   Call Center            SUV      Medsize
# 4   Personal L1           Offer1         Agent  Four-Door Car      Medsize

# %% [markdown]
# It does not make sence for effective to date to become a categorical variable,it should be the datetime type.

# %% [markdown]
# # 6.Does any column contain alpha and numeric data? Decide how to clean it.

# %%
categorical_df['Customer'] = categorical_df['Customer'].str[2:]#for customer,we can delete the first two letter,only keep the number

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor           2/24/11
# 1    44356     Arizona       No  Extended  Bachelor           1/31/11
# 2    49188      Nevada       No   Premium  Bachelor           2/19/11
# 3    63253  California       No     Basic  Bachelor           1/20/11
# 4    64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0  Corporate L3           Offer1         Agent   Two-Door Car      Medsize
# 1   Personal L3           Offer3         Agent  Four-Door Car      Medsize
# 2   Personal L3           Offer1         Agent   Two-Door Car      Medsize
# 3  Corporate L2           Offer1   Call Center            SUV      Medsize
# 4   Personal L1           Offer1         Agent  Four-Door Car      Medsize

# %%
categorical_df['Renew Offer Type'] = categorical_df['Renew Offer Type'].str[-1:]#for Renew Offer Type,we can delete the offer,only keep the number

# %%
categorical_df.head()
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0    79786  Washington       No     Basic  Bachelor           2/24/11
# 1    44356     Arizona       No  Extended  Bachelor           1/31/11
# 2    49188      Nevada       No   Premium  Bachelor           2/19/11
# 3    63253  California       No     Basic  Bachelor           1/20/11
# 4    64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0  Corporate L3                1         Agent   Two-Door Car      Medsize
# 1   Personal L3                3         Agent  Four-Door Car      Medsize
# 2   Personal L3                1         Agent   Two-Door Car      Medsize
# 3  Corporate L2                1   Call Center            SUV      Medsize
# 4   Personal L1                1         Agent  Four-Door Car      Medsize

# %% [markdown]
# # 7.Would you choose to do anything else to clean or wrangle the categorical data? Comment your decisions.

# %% [markdown]
# Yes,I will cast the effective to date into datetype.

# %%
categorical_df['Effective To Date']=pd.to_datetime(categorical_df['Effective To Date'])
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0       79786  Washington       No     Basic  Bachelor        2011-02-24
# 1       44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2       49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3       63253  California       No     Basic  Bachelor        2011-01-20
# 4       64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129    72316  California       No     Basic  Bachelor        2011-02-10
# 9130    87824  California      Yes  Extended   College        2011-02-12
# 9131    14365  California       No  Extended  Bachelor        2011-02-06
# 9132    19263  California       No  Extended   College        2011-02-03
# 9133    67826  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# 1          Unemployed      F      Suburban         Single   Personal Auto
# 2            Employed      F      Suburban        Married   Personal Auto
# 3          Unemployed      M      Suburban        Married  Corporate Auto
# 4            Employed      M         Rural         Single   Personal Auto
# ...               ...    ...           ...            ...             ...
# 9129         Employed      M         Urban        Married   Personal Auto
# 9130         Employed      F      Suburban       Divorced  Corporate Auto
# 9131       Unemployed      M      Suburban         Single  Corporate Auto
# 9132         Employed      M      Suburban        Married   Personal Auto
# 9133       Unemployed      M      Suburban         Single  Corporate Auto
#
#             Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0     Corporate L3                1         Agent   Two-Door Car      Medsize
# 1      Personal L3                3         Agent  Four-Door Car      Medsize
# 2      Personal L3                1         Agent   Two-Door Car      Medsize
# 3     Corporate L2                1   Call Center            SUV      Medsize
# 4      Personal L1                1         Agent  Four-Door Car      Medsize
# ...            ...              ...           ...            ...          ...
# 9129   Personal L1                2           Web  Four-Door Car      Medsize
# 9130  Corporate L3                1        Branch  Four-Door Car      Medsize
# 9131  Corporate L2                1        Branch  Four-Door Car      Medsize
# 9132   Personal L2                3        Branch  Four-Door Car        Large
# 9133  Corporate L3                4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 16 columns]

# %% [markdown]
# # 8.Compare policy_type and policy. What information is contained in these columns. Can you identify what is important?

# %% [markdown]
# the policy type already defined the type,so the policy don't need this information again,so we can just keep the level number in the policy.

# %%
categorical_df['Policy'] = categorical_df['Policy'].str[-1:]
categorical_df
# Out:
#      Customer       State Response  Coverage Education Effective To Date  \
# 0       79786  Washington       No     Basic  Bachelor        2011-02-24
# 1       44356     Arizona       No  Extended  Bachelor        2011-01-31
# 2       49188      Nevada       No   Premium  Bachelor        2011-02-19
# 3       63253  California       No     Basic  Bachelor        2011-01-20
# 4       64268  Washington       No     Basic  Bachelor        2011-02-03
# ...       ...         ...      ...       ...       ...               ...
# 9129    72316  California       No     Basic  Bachelor        2011-02-10
# 9130    87824  California      Yes  Extended   College        2011-02-12
# 9131    14365  California       No  Extended  Bachelor        2011-02-06
# 9132    19263  California       No  Extended   College        2011-02-03
# 9133    67826  California       No  Extended   College        2011-02-14
#
#      EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0            Employed      F      Suburban        Married  Corporate Auto
# 1          Unemployed      F      Suburban         Single   Personal Auto
# 2            Employed      F      Suburban        Married   Personal Auto
# 3          Unemployed      M      Suburban        Married  Corporate Auto
# 4            Employed      M         Rural         Single   Personal Auto
# ...               ...    ...           ...            ...             ...
# 9129         Employed      M         Urban        Married   Personal Auto
# 9130         Employed      F      Suburban       Divorced  Corporate Auto
# 9131       Unemployed      M      Suburban         Single  Corporate Auto
# 9132         Employed      M      Suburban        Married   Personal Auto
# 9133       Unemployed      M      Suburban         Single  Corporate Auto
#
#      Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size
# 0         3                1         Agent   Two-Door Car      Medsize
# 1         3                3         Agent  Four-Door Car      Medsize
# 2         3                1         Agent   Two-Door Car      Medsize
# 3         2                1   Call Center            SUV      Medsize
# 4         1                1         Agent  Four-Door Car      Medsize
# ...     ...              ...           ...            ...          ...
# 9129      1                2           Web  Four-Door Car      Medsize
# 9130      3                1        Branch  Four-Door Car      Medsize
# 9131      2                1        Branch  Four-Door Car      Medsize
# 9132      2                3        Branch  Four-Door Car        Large
# 9133      3                4   Call Center   Two-Door Car      Medsize
#
# [9134 rows x 16 columns]

# %% [markdown]
# # 9.Check number of unique values in each column, can they be combined in any way to ease encoding? Comment your thoughts and make those changes.

# %%
categorical_df['Education'].value_counts()
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
categorical_df['Vehicle Class'].value_counts()
# Out:
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Sports Car        484
# Luxury SUV        184
# Luxury Car        163
# Name: Vehicle Class, dtype: int64

# %%
# need = categorical["education"].value_counts().index[:3]
# categorical["education"] = np.where(categorical["education"].isin(need), categorical["education"], 'Post-Uni')
# categorical["education"].value_counts(dropna=False)

# %% [markdown]
# By looking at the number of unique values,I find that we can combine Master and Doctor for Education variable because both of them are just a small amount.The same for Sports Car, Luxury SUV and Luxury Car for Vehicle Class variable.

# %%
categorical_df["Education"].loc[categorical_df["Education"].isin(['Master','Doctor'])] = "Post-Uni"
categorical_df["Education"].value_counts(dropna=False)
# Out:
# C:\Users\duyadong\AppData\Local\Temp\ipykernel_8804\399086681.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df["Education"].loc[categorical_df["Education"].isin(['Master','Doctor'])] = "Post-Uni"
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Post-Uni                1083
# Name: Education, dtype: int64

# %%
categorical_df["Vehicle Class"].loc[categorical_df["Vehicle Class"].isin(['Sports Car','Luxury SUV','Luxury Car'])] = "Facy Car"
categorical_df["Vehicle Class"].value_counts(dropna=False)
# Out:
# C:\Users\duyadong\AppData\Local\Temp\ipykernel_8804\1884358328.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical_df["Vehicle Class"].loc[categorical_df["Vehicle Class"].isin(['Sports Car','Luxury SUV','Luxury Car'])] = "Facy Car"
# Four-Door Car    4621
# Two-Door Car     1886
# SUV              1796
# Facy Car          831
# Name: Vehicle Class, dtype: int64
